# %% [markdown]
# Take a number and print its square using exponent operator

# %%
n = int(input("Enter any value "))
a = n **2
print("The Square of Number n = ",a)
# Out:
# Enter any value 5
# The Square of Number n =  25

# %% [markdown]
# Take a number and print its cube

# %%
n = int(input("Enter any value "))
a = n **3
print("The Cube of Number n = ",a)
# Out:
# Enter any value 2
# The Square of Number n =  8

# %% [markdown]
# Take two numbers and print the result of floor division.

# %%
a = int(input("Enter value of a "))
b = int(input("Enter value of b "))
c = a//b
print(f"The Result of Floor division {a} and {b} = ",c)
# Out:
# Enter value of a 5
# Enter value of b 2
# The Result of Floor division 5 and 2 =  2

# %% [markdown]
# Take two numbers and print the result of exponentiation (a raised to power b)

# %%
a = int(input("Enter value of a "))
b = int(input("Enter value of b "))
c = a **b
print(f"The exponential result of {a} exponent {b} = ",c)
# Out:
# Enter value of a 2
# Enter value of b 3
# The exponential result of 2 exponent 3 =  8

# %% [markdown]
# Take a number and find the last digit of the number.

# %%
a = int(input("Enter any value of a "))
c = a % 10
print(f"The last number of given value of {a} = ",c)
# Out:
# Enter any value of a 2
# The last number of given value of 2 =  2

# %% [markdown]
# Take a number and check:number divided by 2 using division,number divided by 2 using floor division

# %%
number = int(input("Enter the number "))
a = number / 2
b = number //2
print(f"The {number} didvided by 2 is {a} and the number divided by 2 using floor division is {b}")
# Out:
# Enter the number 123
# The 123 didvided by 2 is 61.5 and the number divided by 2 using floor division is 61

# %% [markdown]
# Take total marks and number of subjects, calculate average marks.

# %%
a = 75
b = 56
c = 89
d = 99
e = 78
total_marks = a+b+c+d+e
total_subjects = 5
ave_marks = total_marks/total_subjects
print("The average marks of a student = ",ave_marks)
# Out:
# The average marks of a student =  79.4

# %% [markdown]
# Take a price and quantity, calculate total bill amount.

# %%
a = int(input("Enter the price of a object "))
b = int(input("Enter how many quantity you need "))
total_bill = a * b
print(" The total bill = ",total_bill)
# Out:
# Enter the price of a object 20
# Enter how many quantity you need 5
#  The total bill =  100

# %% [markdown]
# Take base and height of a triangle and find area.

# %%
b = int(input("Enter base "))
h = int(input("Enter height "))
area = (1/2)*(b*h)
print(area)
# Out:
# Enter base 2
# Enter height 4
# 4.0

# %% [markdown]
# Take total seconds and convert into minutes and remaining seconds.

# %%
total_sec = int(input("Enter how many seconds"))
hour = total_sec // 3600
rem_sec = total_sec % 3600
min = rem_sec // 60
sec = total_sec % 60
print(f"Time = {hour} hour {min} minute {sec}seconds ")
# Out:
# Enter how many seconds7199
# Time = 1 hour 59 minute 59seconds

# %%
a = 7200/60
print(a)
# Out:
# 120.0

# %% [markdown]
# Take a number and calculate:half using division:half using floor division

# %%
n = 10
div = n / (0.5)
f_div = n//(0.5)
print(div,f_div)
# Out:
# 20.0 20.0

# %% [markdown]
# Take monthly salary and calculate yearly salary

# %%
a = int(input("Enter the salary per month "))
b = a * 12
print("The early salary of a employee = ", b)
# Out:
# Enter the salary per month 5000
# The early salary of a employee =  60000

# %% [markdown]
# Take salary and calculate 10% tax amount.

# %%
a = int(input("Enter the salary per month "))
b = a / 10
print("Tax amount of  employee = ", b)
# Out:
# Enter the salary per month 1000000
# The early salary of a employee =  100000.0

# %% [markdown]
# Take total minutes and convert into hours and minutes.

# %%
n = int(input("Enter minutes "))
hour = n // 60
min = n % 60
print(f" {hour} hours and {min} minutes")
# Out:
# Enter minutes 121
#  2 hours and 1 minutes

# %% [markdown]
# Take total days and convert into weeks and remaining days

# %%
a = int(input("Enter the number from 1 - 31 "))
week = a // 7
day = a % 7
print(f"{week} weeks and {day} days ")
# Out:
# Enter the number from 1 - 31 9
# 1 weeks and 2 days

# %% [markdown]
# Take total distance in meters and convert into kilometers and meters.

# %%
a = int(input("Enter meter "))
Km = a // 1000
m = a % 1000
print(f" {Km} km and {m} meter ")
# Out:
# Enter meter 1001
#  1 km and 1 meter

# %% [markdown]
# Take obtained marks and calculate remaining marks to reach full marks.

# %%
a = int(input("Enter the total marks for which exam is done"))
b = int(input("Enter the marks obtained "))
c = a - b
print("The  marks need to score total marks = ", c)
# Out:
# Enter the total marks for which exam is done450
# Enter the marks obtained 400
# The  marks need to score total marks =  50

# %% [markdown]
# Take a number and find its last two digits.

# %%
a = int(input("Enter the numbers "))
b = a % 10 #gives remainder that is last value
c = a // 10
d = c % 10
print(f"The last two digits are {d},{b}")
# Out:
# Enter the numbers 1009876
# The last two digits are 7,6

# %% [markdown]
# Take a number and remove its last digit.

# %%
a = int(input("Enter the numbers "))
n = a // 10
print(n)
# Out:
# Enter the numbers 1527756
# 152775

# %% [markdown]
# Take a number and find its middle digit (3-digit number).

# %%
a = int(input("Enter the 3 numbers "))
n = a //10
c = n % 10
print(c)
# Out:
# Enter the 3 numbers 1234567
# 6

# %% [markdown]
# Take total hours worked and hourly wage, calculate total pay.

# %%
a = int(input("Enter amount payed for working 1 hr a day "))
b = int(input("Enter total hours worked (0-24)"))
total_pay = a * b
print(f"total wages = {total_pay} Rupees ")
# Out:
# Enter amount payed for working 1 hr a day 9000
# Enter total hours worked (0-24)1
# total wages = 9000 Rupees
