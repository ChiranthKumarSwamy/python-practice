# %% [markdown]
# Write a program to check whether a number is greater than 100.

# %%
a = int(input("Enter a number"));
print(a>100)
# Out:
# Enter a number5
# False

# %% [markdown]
# Write a program that:
#
# Takes a number
#
# Multiplies it by 3 using an assignment operator

# %%
a = int(input("Enter a number"));
a *= 3
print(a)
# Out:
# Enter a number3
# 9

# %% [markdown]
# x = 15
# print(x > 10 and x < 20)

# %%
x = 15
print(x > 10 and x < 20) #true
# Out:
# True

# %% [markdown]
# Write a program to check:
#
# A number is between 50 and 100 (inclusive)

# %%
a = int(input("enter a "))
print(a> 50 and a < 100 );
# Out:
# enter a 99
# True

# %% [markdown]
# Find final value x = 10
# x *= 2
# x += 5
# x -= 3

# %%
x = 10
x*= 2
x+= 5
x-= 3    #10 *2 = 20 . 20+5 = 25 . 25-3= 22
print(x)
# Out:
# 22

# %% [markdown]
# Write a program that:
#
# Takes a number
#
# Adds 10
#
# Divides by 2
# (using assignment operators only)

# %%
a = int(input("enter a "))
a += 10
a /= 2
print(a) # 2 +10 = 12 , 12/2 = 6
# Out:
# enter a 2
# 6.0

# %% [markdown]
# print(True or False and False)

# %%
print(True or False and False) #****
# Out:
# True

# %% [markdown]
# x = 8
# y = 12
# z = 4
# print(x > y and y > z or z < x)

# %%
x = 8
y = 12
z = 4
print(x > y and y > z or z < x)  #false and true = false or true = true
# Out:
# True

# %% [markdown]
# Write a program to check:
#
# Age ≥ 18 AND
#
# Citizen = True
# → Eligible to vote

# %%
a = int(input("Enter  a number "))
citizen = True
b = a>=18 and citizen == True
print(b)
# Out:
# Enter  a number 19
# True

# %% [markdown]
# Write a program that:
#
# Takes marks
#
# Adds grace marks using +=
#
# Checks pass (marks ≥ 40)

# %%
a = int(input("Enter  a number "))
grace_marks = int(input("Enter  a number "))
a += grace_marks
pass_marks = a>=40
print(pass_marks,a)
# Out:
# Enter  a number 40
# Enter  a number 1
# True 41

# %%
print((5 > 3) == True)
# Out:
# True

# %%
print(8 & 1 == 0)
# Out:
# True

# %%
print(4 * 2 > 7 and 3 + 1 == 4)
print(6 | 1 > 6)
# Out:
# True
# True

# %%
a = 7
b = 3
print(a + b & a == 10)
# Out:
# False

# %%
print(8 >> 1 + 1 == 2)
# Out:
# True

# %%
a = 3
b = 5
print(a * b & a + b == 7)
# Out:
# False

# %%
a = 6
print(a & 1 == 0 and a * 2 > 10 or a + 1 == 7)
# Out:
# True

# %%
a = 10
b = 5
print(a + b & a == 15)
# Out:
# False
