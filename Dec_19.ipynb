# %% [markdown]
# Comparision operator - 1 ) Greater a>b . 2) smaller a<b . 3) Equal to a==b . 4) Not equal to != . 5) Greater or equal to >= . 6) less than or equal <= .

# %%
a = int(input("Enter value of a "))
b = int(input ("Enter value of b"))
print(f"a>b:{a>b}")
print(f"a<b:{a<b}")
print(f"a==b:{a==b}")
print(f"a!=b:{a!=b}")
print(f"a>=b:{a>=b}")
print(f"a<=b:{a<=b}")
# Out:
# Enter value of a 10
# Enter value of b2
# a>b:True
# a<b:False
# a==b:False
# a!=b:True
# a>=b:True
# a<=b:False

# %% [markdown]
# Assignment Operator : 1) = . a = 5 . 2) += . a = 5 a+=5 a = a+5 a=5+5 a = 10 . 3)-= . 4)*= 5 ) /= 6) //= 7)**=

# %%
# 1
a = 5
print(a)
# Out:
# 5

# %%
# 2
a = 5
a += 10
print(a);
# Out:
# 15

# %%
# 3
a = 5
a *= 10 ;
print(a);
# Out:
# 50

# %%
#4
a = 5
a /= 10 ;
print(a);
# Out:
# 0.5

# %%
#5
a = 5
a //= 10
print(a);
# Out:
# 0

# %%
#6
a = 2
a**= 2 ;
print(a);
# Out:
# 4

# %% [markdown]
# Logical operator . 1) and [True and true is true all other false ] 2) or [One true is true and only 0 - 0 is false ] 3)not  [True is false and false is true  ] xor [same same - 0 . different - 1]

# %%
print(True and False )
print(True and True )
# Out:
# False
# True

# %%
a = 10
b = 15
print(a==b or a<b);
# Out:
# True

# %% [markdown]
# Bitwise opeartor =  Decimal to Binary  and Binary to Decimal . Convert decimal to binary and binary to decimal  1 - > on . 0 -> off . And & . or | not ~

# %%
5 & 7
# Out:
# 5

# %%
11 | 18
# Out:
# 27

# %%
9 ^ 19
# Out:
# 26

# %%
~ 23
# Out:
# -24

# %%
# logic operator
a = 10
b = 15
print(f"a&b :{a&b}")
print(f"a|b :{a|b}")
print(f"a^b :{a^b}")
print(f"not a :{ ~a}");
print(f"left shift a<<1:{a<<1}") # add 0 in right
print(f"right shift a>>1:{a>>1}") # add 0 in left and remove last digit
# Out:
# a&b :10
# a|b :15
# a^b :5
# not a :-11
# left shift a<<1:20
# right shift a>>1:5

# %% [markdown]
# Indentation -

# %%
print("Hi");
print("hello")
# Out:
# Hi
# hello

# %% [markdown]
# input a number from user

# %%
a = int(input("Enter the number "));
if (a>=0):
  print("a is positive")
else :
  print("a is negative ")
# Out:
# Enter the number -10
# a is negative
