# %% [markdown]
# Write a program to check whether two numbers are equal or not.

# %%
a = 10
b = 10
print(a==b)
# Out:
# True

# %% [markdown]
# Even or Odd

# %%
a = 11
b = a%2 == 0
print(b)
# Out:
# False

# %% [markdown]
# Eligible to Vote

# %%
a = int(input("Enter a number "))
b = a > 18
print(f"The legal age for voting is 18 and the age of the candidte is {a} ",b)
# Out:
# Enter a number 11
# The legal age for voting is 18 and the age of the candidte is 11  False

# %% [markdown]
# Check whether num is greater than or equal to 10.

# %%
a = int(input("Enter a number "))
b = a >=10
print(b)
# Out:
# Enter a number 11
# True

# %% [markdown]
# Float Comparison
#
# Check whether 7.0 is equal to 7.

# %%
a = 7
b = 7.0
print(a>b)
# Out:
# False

# %% [markdown]
# Check whether x lies between 5 and 10.

# %%
x = int(input("Enter a number "))
b = 5 <= x <=10
print(b)
# Out:
# Enter a number 1
# True

# %%
# a = 62
# b = 6
# c = (b * (a // b )) + (a % b )
# print(c)

Divident = int(input("Enter the value of a "))
Divisor = int(input("Enter the value of a "))
Quoteint = Divident // Divisor
Reminder = Divident % Divisor
Output = (Divisor * Quoteint ) + Reminder
print(f" Divident {Divident} = Output {Output}")
# Out:
# Enter the value of a 62
# Enter the value of a 6
#  Divident 62 = Output 62

# %%
total_sec = int(input("Enter the sec"))
hour = total_sec // 3600
rem_time = total_sec % 3600
min = rem_time // 60
sec = rem_time % 60
print(f"{hour} hours :{min} min : {sec}sec :")
# Out:
# Enter the sec4250
# 1 hours :10 min : 50sec :

# %%
n = int(input("Enter total number on days "))
year = n // 365
rem_day = n % 365
months = rem_day // 30
days = rem_day % 30
print(f" {year} years {months} month {days}days ")
# Out:
# Enter total number on days 29
#  0 years 0 month 29days
