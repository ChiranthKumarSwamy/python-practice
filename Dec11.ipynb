# %% [markdown]
# Naming a variable .
# 1.start with _ or alphabet . a-z , A-z , _
# 2.Do not use special charatcter $,@ etc . Do not use numbers 1chiru
# 3.It is case sensitive chiru !=Chiru
# 4.Good way is use lower case . user_name
# 5.user-name is not possible . hypen can not be used

# %%
_a = 10
print(_a)
# Out:
# 10

# %%
1_a = 10
print(1_a)
# Out:
#   File "/tmp/ipython-input-856235790.py", line 1
#     1_a = 10
#      ^
# SyntaxError: invalid decimal literal

# %%
user_name = 10
print(user_name)
# Out:
# 10

# %%
user-name = 10
print(user-name)
# Out:
#   File "/tmp/ipython-input-1754732287.py", line 1
#     user-name = 10
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a = "100"
print(a)
print(type(a))
# Out:
# 100
# <class 'str'>

# %% [markdown]
# Naming can be done in two ways . a = 10 , b = 20 , c to store a value  or a,b=10,20

# %% [markdown]
# Swapping two number . 2 ways .

# %%
a = 10
b = 20
c = a
a = b
b = c
print(a,b)
# Out:
# 20 10

# %%
a = 10
b = 20
a,b = b , a
print (a,b)
# Out:
# 20 10

# %% [markdown]
# we can assign values in 2 types . One is a = 10 and b = 20 and the other is a , b = 10 , 20

# %%
a = 10
b = 20
print (a,b)
# Out:
# 10 20

# %%
a,b = 10,20
print(a,b)
# Out:
# 10 20

# %% [markdown]
# Arithametic operations . Addition (+) . Subtraction (-) . Multiplication (*) . Division (/) . Floor (//) . Modulus (%)  . Power **

# %%
a = 10
b = 2
print(a+b) # 12
print(a-b) # 8
print(a*b) # 20
print(a/b) #5
print(a//b) # 5
print(a%b) # 0
print(a**b) #100
# Out:
# 12
# 8
# 20
# 5.0
# 5
# 0
# 100

# %% [markdown]
# 1.Area of cirrcle a = pie *r*
# 2.Pythagoras Theorem = c**2 = a**2 +b**2
# 3.Simple interest
# 4.Compound Intrest .

# %%
# Area of circle
pie = 3.14
radius = 5
area_of_circle = pie * (radius**2)
print("Area of circle = ",area_of_circle)
# Out:
# Area of circle =  78.5

# %%
#Pythagoras Theorem
a = 10
b = 2
c = ((a**2) + (b**2))**0.5
print("Pythagoras Theorem = ", c)
# Out:
# Pythagoras Theorem =  10.198039027185569

# %% [markdown]
# Formatting - f {}

# %%
a = "Chiru"
b = 23
print(f" I am {a} and i am {b} years old ")
# Out:
#  I am Chiru and i am 23 years old
